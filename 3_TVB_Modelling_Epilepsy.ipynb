# %% [markdown]
# # Modeling Epileptic seizures using TVB

# %% [markdown]
# **ABC Summer School, Amsterdam, June 22nd, 2022**

# %% [markdown]
# ## Context
#
# <p>TVB can be used to model <b>large-scale epileptic seizure dynamics</b>. Using relevant neural mass models, TVB allows to ask multiple questions such as the <b>localisation of the Epileptogenic Zone</b> or the <b>validity of different neuroimaging modalities</b> to assess the epileptogenicity of a brain structure. Here, we will present an example of such a modelisation.</p>
#
# ![](images/seizures_epilepsy.jpg)

# %% [markdown]
# ## Objectives
#
# The main goal of this tutorial is to provide a clear understanding of <b>how we can reproduce clinically relevant senarios</b> such as the modelisation of <b>propagation of an epileptic seizure</b> in the human brain, <b>surgical resection</b> of brain regions, and <b>electrical stimulation</b> of a brain region that can trigger a seizure.

# %% [markdown]
# ## How to do it with TVB?
#
# The first thing we want to do is to import the modules we will need for a simulation.

# %%
# %%capture
# Import a bunch of stuff to ease command line usage.
from tvb.simulator.lab import *
from tvb.datatypes.time_series import TimeSeriesRegion
import tvb.datatypes.projections as projections
from utils import plot_connectivity
from phase_plane import phase_plane_interactive

import numpy as np
import matplotlib.pyplot as plt
import os
import time as tm

# %% [markdown]
# ## 1. Exploring the Epileptor model
# In order to model epilepsy, we choose the Epileptor, which is a phenomenological neural mass model able to realistically reproduce epileptic seizure dynamics (see Jirsa et al., Brain 2014).
#
# Before launching any simulations, let's have a look at the phase space of the model in order to better understand its dynamics.

# %%
# Create an Epileptor model instance.
epi = models.Epileptor()

# Initialise an Integrator scheme.
dt = 0.075    #integration steps [ms]
heunint = integrators.HeunDeterministic(dt=dt)

# Open the phase plane tool with the Epileptor model.
phase_plane_interactive(model=epi, integrator=heunint)
# Out:
# interactive(children=(FloatSlider(value=0.00035, description='r', max=0.001), FloatSlider(value=-1.6, descript…
# <function phase_plane.phase_plane_interactive.<locals>.plot_phase_plane(**param_kwargs)>

# %% [markdown]
# <p><div style="text-align: justify">Look at the phase space:
# <br>
# <ul>
# <li>We have here the <b>first population (variables $\pmb{x_{1}}$ in abscissa and $\pmb{y_{1}}$ in ordinate)</b>.
#
# The left most intersection of the two nullclines defines a <b>stable fixed point</b>, representing the <b>interictal state (i.e., between seizures)</b>, whereas the right most intersection is the center of a <b>limit cycle</b>, being the <b>ictal state (i.e., during seizures)</b>. Both states are separated by a separatrix, as you can se by drawing different trajectories in this phase space.</li><br>
#
# <li>You can also have a look at other variables in the phase space, such as the <b>second population (variables $\pmb{x_{2}}$ in abscissa and $\pmb{y_{2}}$ in ordinate)</b>, responsible for the <b>interictal spikes</b> in the Epileptor model. Change the lower and upper bound of the axis to see correctly the phase space.</li>
#
# <br><li>You can continue to play along to explore the dynamics of this model. For instance, try changing the number of integration steps, or choosing a HeunStochastic integrator and varying the scaling of the noise:</li>
# </ul></div></p>

# %%
epi = models.Epileptor()
# Initialise a stochastic Integrator scheme.
dt = 0.01                                           #integration steps [ms]
heunstochint = integrators.HeunStochastic(dt=dt)
heunstochint.noise.nsig = np.r_[0.1]                      #standard deviation of the noise 

# Open the phase plane tool with the Epileptor Model and stochastic Integrator.
phase_plane_interactive(model=epi, integrator=heunstochint)
# Out:
# interactive(children=(FloatSlider(value=0.00035, description='r', max=0.001), FloatSlider(value=-1.6, descript…
# <function phase_plane.phase_plane_interactive.<locals>.plot_phase_plane(**param_kwargs)>

# %% [markdown]
# <h1>2. Dataset</h1>
# <br>
# <p>We will use the <b>default dataset</b> that is supplied with The Virtual Brain. To make things fully transparent, we will load the files from our local copy. To follow, change the path to the location of the dataset on your machine:</p>

# %%
datadir = os.path.abspath("./dataset")

# %% [markdown]
# <h1>3. Region-based modeling of an epileptic patient</h1>
# <br>
# <p>In the following, we will model a patient with a <b>bilateral temporal lobe epilepsy (TLE)</b> using the Default TVB Subject.</p> <br>
#
# <p>The basic simulation of TVB consists of 5 main components. Each of these components is an object within TVB:</p>

# %% [markdown]
# <h2> 3.1 Structural Connectivity</h2>
#
# <p>We start with loading and visualizing the structural connectivity matrix.</p>

# %%
# Initialise a Connectivity.
con = connectivity.Connectivity.from_file(os.path.join(datadir, "connectivity_76.zip"))       
nregions = len(con.areas)                                  #number of regions
con.weights = con.weights - con.weights * np.eye(nregions) #remove self-connections
con.weights = con.weights / np.abs(con.weights.max())      #normalize
con.speed = np.array(np.inf)                                         #set the conduction speed to infinity (i.e., no time delay)
con.configure()

# %%
# Visualization.
plot_connectivity(con)

# %% [markdown]
# <h2> 3.2 Model</h2>
#
# <p>A set of differential equations describing the local dynamics. Here, we use the <b>Epileptor</b>.</p>

# %%
# Initialise a Model.
epi = models.Epileptor(Ks=np.array(1.), r=np.array(0.00015))

# Set initial conditions.
epi.state_variable_range["x1"] = [-1.8, -1.4]
epi.state_variable_range["y1"] = [-15., -10.]
epi.state_variable_range["z"] = [3.6, 4.]
epi.state_variable_range["x2"] = [-1.1, -0.9]
epi.state_variable_range["y2"] = [0.001, 0.01]

# %% [markdown]
# <p>We can refine the network pathology of the patient by including the hypothesis about the Epileptogenic Network. To this end, we define a <b>spatial map of epileptogenicity</b> where each network's node <i>i</i> is characterized by an excitability value $\pmb{x_{0,i}}$, which quantifies its ability to trigger a seizure.
# <br>We set:
# <ul>
# <li>the hippocampus (rHC, region 9 and lHC, region 47) as well as the amydala (rAMYG, region 2 and lAMYG, region 40)
# as <b>Epileptogenic Zone (EZ)</b>, with an epileptogenicity parameter value $\pmb{x_{0,i}}$ equal to <b>-0.75</b> for the rHC and <b>-1.65</b> for the lHC and l-rAMYG,</li>
# <li>we also add two lesser epileptogenic regions: the parahippocampal (lPHC, region 62) and the temporal pole (lTPOL, region 70) as <b>Propagation Zone (PZ)</b>, with an epileptogenicity parameter value $\pmb{x_{0,i}}$ equal to <b>-1.78</b> and <b>-1.81</b>, respectively,</li>
# <li>and all the other regions (or <b>Non-Epileptogenic Zone, NEZ</b>) are set to <b>-2.6</b>.</li>
# </ul>

# %%
# Define a heatmap.
epi.x0 = np.ones(nregions) * (-2.6)            #NEZ
epi.x0[[9]] = np.ones((1)) * (-0.75)           #EZ 
epi.x0[[47, 2, 40]] = np.ones((3)) * (-1.65)   #EZ 
epi.x0[[62]] = np.ones((1)) * (-1.78)          #PZ 
epi.x0[[70]] = np.ones((1)) * (-1.81)          #PZ

# %% [markdown]
# <h2> 3.3 Coupling function</h2>
#
# <p><div style="text-align: justify">It is a function that is used to join the local model dynamics at distinct spatial locations.</div></p>
#
# <p><div style="text-align: justify">We couple the Epileptors by permittivity coupling, which quantifies the influence of neuronal fast discharges $x_{1,j}$ of a remote region $j$ on the local slow permittivity variable $z_{i}$ of region $i$ via a linear <b>difference coupling</b> function.</div></p>

# %%
# Initialise a Coupling function.
G = np.array(-0.25)      #global (long-range) coupling strength
con_coupling = coupling.Difference(a=G)

# %% [markdown]
# <h2>3.4 Integrator</h2>
#
# <p><div style="text-align: justify">We use a stochastic integration scheme, and the noise is added. The shape of the noise must correspond to the number of state-variables in the neural mass model, here equal to 6. </div></p>
#
# <p><div style="text-align: justify">We employ a standard <b>Heun method</b> with an integration time step of <b>0.05</b>. <b>Additive white Gaussian noise</b> is introduced in the state-variables $\pmb{x_{2,i}}$ and $\pmb{y_{2,i}}$ with 0 mean and variance <b>0.00025</b>. Other variables experience only little or no noise due to their high density.</div></p>

# %%
# Initialise an Integrator scheme.
dt = 0.05               #integration steps [ms]
nsigma = 0.0001        #standard deviation of the noise

hiss = noise.Additive(nsig=np.array([0., 0., 0., nsigma, nsigma, 0.])) 
heunint = integrators.HeunStochastic(dt=dt, noise=hiss)

# %% [markdown]
# <h2> 3.5 Monitors</h2>
#
# <p>The last component we need to define are some Monitors. Monitors are measurement processes applied to the output data from the simulation.
# <pre></pre>
#
# Here, we will select (1) a simple data reduction and (2) a biophysical measurement process to relate the simulated neural activity to recent epilepsy studies:
#
# <ol type="1">
# <li>the <b>TemporalAverage</b> monitor averages over a time window of length <i>period</i> returning one time point every <i>period</i> ms,</li>
# <li>the <b>iEEG</b> monitor generates SEEG recordings.</li>
# </ol>
# </font></div></p>

# %%
# Initialise some Monitors with period in physical time.
mon_tavg = monitors.TemporalAverage(period=1) #in ms

mon_seeg = monitors.iEEG.from_file(
    sensors_fname=os.path.join(datadir, "seeg_588.txt"),
    projection_fname=os.path.join(datadir, "projection_seeg_588_surface_16k.npy"),
    rm_f_name=os.path.join(datadir, "regionMapping_16k_76.txt"),
    period=1.)

what_to_watch = (mon_tavg, mon_seeg)

# %% [markdown]
# ***

# %% [markdown]
# <h1 align="center">Go! Simulate</h1>
#
# <p>We can then configure and run the <b>Simulator</b>.</p>

# %%
# Initialise the Simulator.
sim = simulator.Simulator(model=epi,
                          connectivity=con,
                          conduction_speed=float(con.speed),
                          coupling=con_coupling,
                          integrator=heunint,
                          monitors=what_to_watch)

sim.configure()
# Out:
# <table>
# <h3>Simulator</h3>
# <thead><tr><th></th><th style="text-align:left;width:40%">value</th></tr></thead>
# <tbody>
# <tr><td>Type</td><td style="text-align:left;"><pre>Simulator</pre></td>
# <tr><td>conduction_speed</td><td style="text-align:left;"><pre>inf</pre></td>
# <tr><td>connectivity</td><td style="text-align:left;"><pre>Connectivity gid: 81b92a0b-4dab-4d53-bdd0-0ca5c6de9434</pre></td>
# <tr><td>coupling</td><td style="text-align:left;"><pre>Difference gid: e9c3b126-42ab-4cf7-a4d6-e1ab7498001c</pre></td>
# <tr><td>gid</td><td style="text-align:left;"><pre>UUID('efcd69a7-3149-473b-9c22-f5ab90d1dac9')</pre></td>
# <tr><td>initial_conditions</td><td style="text-align:left;"><pre>None</pre></td>
# <tr><td>integrator</td><td style="text-align:left;"><pre>HeunStochastic gid: 87c3a327-3b1b-46e0-9c11-609038b52acd</pre></td>
# <tr><td>model</td><td style="text-align:left;"><pre>Epileptor gid: d2ee7ab1-39e2-4718-b35a-2323f0a8a036</pre></td>
# <tr><td>monitors</td><td style="text-align:left;"><pre>(<tvb.simulator.monitors.TemporalAverage object at 0x12d2672b0>, <tvb.simulator.monitors.iEEG object at 0x12d267820>)</pre></td>
# <tr><td>simulation_length</td><td style="text-align:left;"><pre>1000.0</pre></td>
# <tr><td>stimulus</td><td style="text-align:left;"><pre>None</pre></td>
# <tr><td>surface</td><td style="text-align:left;"><pre>None</pre></td>
# <tr><td>title</td><td style="text-align:left;"><pre>Simulator gid: efcd69a7-3149-473b-9c22-f5ab90d1dac9</pre></td>
# </tbody></table>

# %%
# Starting simulation. 
print("Starting simulation...")
tic = tm.time()
(ttavg, tavg), (tseeg, seeg) = sim.run(simulation_length=6000) # ~ 64 s

# Finished simulation. 
print("Finished simulation.")
print("execute for" + str(tm.time()-tic))
# Out:
#   0%|          | 186/119999 [00:00<01:04, 1855.74it/s]
# Starting simulation...
# 120000it [00:58, 2053.47it/s]
# Finished simulation.
# execute for58.52061080932617

# %% [markdown]
# ***

# %% [markdown]
# <h1 align="center">Visualize our simulation</h1>
#
# <p>And finally, we can look at the results of our simulation in terms of time series:</p>

# %%
# Normalize the time series to have nice plots.
tavg /= (np.max(tavg,0) - np.min(tavg,0 ))
tavg -= np.mean(tavg, 0)
seeg /= (np.max(seeg,0) - np.min(seeg, 0))
seeg -= np.mean(seeg, 0)

# %%
# Plot neural activity time series.
plt.figure(figsize=(10,10))
plt.plot(ttavg[:], tavg[:, 0, :, 0] + np.r_[:nregions], 'k', alpha=0.1)
plt.title('Epileptors time series', fontsize=15)
plt.xlabel('Time [ms]', fontsize=15)
plt.yticks(np.arange(len(con.region_labels)), con.region_labels, fontsize=6)

EZs = [9, 47, 2, 40]
for ie, ez in enumerate(EZs):
    plt.plot(ttavg[:], tavg[:, 0, EZs[ie], 0] + EZs[ie], 'r') # , 'C3'
PZs = [62, 70]
for ip, pz in enumerate(PZs):
    plt.plot(ttavg[:], tavg[:, 0, PZs[ip], 0] + PZs[ip], 'b') # , 'C0'
    
plt.show()

# %%
# Zoom on the propagation pattern.
EN = [9, 47, 2, 40, 62, 70]
idx = np.arange(len(EN))

plt.figure(figsize=(10,10))
for ie, en in enumerate(EN):
    plt.plot(ttavg[500:], tavg[500:, 0, EN[ie], 0] + idx[ie]) # , 'C0'
    plt.yticks([])
plt.title('Epileptogenic Network time series', fontsize=15)
plt.xlabel('Time [ms]', fontsize=15)

plt.show()

# %%
# Plot some of the SEEG sensors.
electrodes = [20, 90, 140, 200, 290, 480, 540]

plt.figure(figsize=(10,10))
plt.plot(tseeg[:], seeg[:, 0, electrodes, 0] + np.r_[:len(electrodes)]) # , 'C0'
plt.yticks(np.r_[:len(electrodes)], mon_seeg.sensors.labels[electrodes])
plt.title('SEEG', fontsize=15)
plt.xlabel('Time [ms]', fontsize=15)
plt.show()

# %% [markdown]
# <h1>4. Modeling surgical resection</h1>
# <br>
# <p>Surgical resection is used for around 20% of epileptic patient whose seizures are drug- resistant. We will simulate the hypothetic case of a surgical resection of the Epileptogenic Zone.</p>

# %% [markdown]
# <h3 align="left">4.1 Resection</h3>
#
# <p>We set all the connections to the Epileptogenic Zone to 0 in the connectivity matrix. The resection of the Epileptogenic Network is not complete, will it be enough to prevent seizures?</p>

# %%
# All the incoming and outcoming connections of the resected regions are removed:
con.weights[:, [9, 47, 2, 40]] = 0.
con.weights[[9, 47, 2, 40], :] = 0.
con.configure()

# Visualization of the resected connectome.
plt.figure(figsize=(8,8))
plt.imshow(con.weights, interpolation='nearest', aspect='equal', cmap='jet')
plt.title('Lesionned Connectome', fontsize=14)
cb=plt.colorbar(shrink=0.8, ticks=[0, 0.5, 1])
cb.set_label('weights')
plt.xticks(range(0, nregions), con.region_labels, fontsize=8, rotation=90)
plt.yticks(range(0, nregions), con.region_labels, fontsize=8)

plt.show()

# %% [markdown]
# <h3 align="left">4.2 Simulate</h3>
#
# <p>We can now relaunch our first simulation, taking care of replacing the dynamic of the EZ by a stable node, as if the region was resected. The rest of the model is set as before, but we just use a time average monitor.</p>

# %%
# Initialise the Model.
epi = models.Epileptor(Ks=np.array(1.), r=np.array(0.00015))

# Define heatmap.
epi.x0 = np.ones(nregions) * (-2.6)       #NEZ
epi.x0[[62]] = np.ones((1)) * (-1.78)     #PZ 
epi.x0[[70]] = np.ones((1)) * (-1.81)     #PZ 

# Set initial conditions.
epi.state_variable_range["x1"] = [-1.8, -1.8]
epi.state_variable_range["y1"] = [-15, -15]
epi.state_variable_range["z"] = [3.6, 3.6]
epi.state_variable_range["x2"] = [-1.1, -1.1]
epi.state_variable_range["y2"] = [0.001, 0.001]

# %%
# Initialise the Simulator.
sim = simulator.Simulator(model=epi,
                          connectivity=con,
                          conduction_speed=float(con.speed),
                          coupling=coupling.Difference(a=np.array(-0.25)),
                          integrator=integrators.HeunStochastic(dt=0.05 , noise=noise.Additive(nsig=np.array([0., 0., 0., 0.00025, 0.00025, 0.]))),
                          monitors=(monitors.TemporalAverage(period=1),))

sim.configure()
# Out:
# <table>
# <h3>Simulator</h3>
# <thead><tr><th></th><th style="text-align:left;width:40%">value</th></tr></thead>
# <tbody>
# <tr><td>Type</td><td style="text-align:left;"><pre>Simulator</pre></td>
# <tr><td>conduction_speed</td><td style="text-align:left;"><pre>inf</pre></td>
# <tr><td>connectivity</td><td style="text-align:left;"><pre>Connectivity gid: 236af931-2170-493a-a34c-2196e9a5fc30</pre></td>
# <tr><td>coupling</td><td style="text-align:left;"><pre>Difference gid: e494c3db-e009-44ab-aced-5119c78e1107</pre></td>
# <tr><td>gid</td><td style="text-align:left;"><pre>UUID('54784fdc-6179-4074-b447-7e65e04a1322')</pre></td>
# <tr><td>initial_conditions</td><td style="text-align:left;"><pre>None</pre></td>
# <tr><td>integrator</td><td style="text-align:left;"><pre>HeunStochastic gid: 27d19a56-673d-4f1c-bbb4-83470de01408</pre></td>
# <tr><td>model</td><td style="text-align:left;"><pre>Epileptor gid: ebf04a41-b08b-4f07-a447-44140b3124e6</pre></td>
# <tr><td>monitors</td><td style="text-align:left;"><pre>(<tvb.simulator.monitors.TemporalAverage object at 0x12e99d190>,)</pre></td>
# <tr><td>simulation_length</td><td style="text-align:left;"><pre>1000.0</pre></td>
# <tr><td>stimulus</td><td style="text-align:left;"><pre>None</pre></td>
# <tr><td>surface</td><td style="text-align:left;"><pre>None</pre></td>
# <tr><td>title</td><td style="text-align:left;"><pre>Simulator gid: 54784fdc-6179-4074-b447-7e65e04a1322</pre></td>
# </tbody></table>

# %%
# Starting simulation
print("Starting simulation...")
tic = tm.time()

(ttavg, tavg), = sim.run(simulation_length=10000) # ~ 73 s

# Finished simulation. 
print("Finished simulation.")
print("execute for " + str(tm.time()-tic))
# Out:
#   0%|          | 201/199999 [00:00<01:39, 2004.49it/s]
# Starting simulation...
# 200000it [01:28, 2268.17it/s]
# Finished simulation.
# execute for 88.1958270072937

# %% [markdown]
# <h3 align="left">4.3 Visualize</h3>

# %%
# Normalize the time series to have nice plots.
tavg /= (np.max(tavg,0) - np.min(tavg,0 ))
tavg -= np.mean(tavg, 0)

# Plot time series.
plt.figure(figsize=(10,10))
plt.plot(ttavg[:], tavg[:, 0, :, 0] + np.r_[:nregions], alpha=0.3) # , 'C2'
plt.title('Res - Epileptors time series', fontsize=15)
plt.xlabel('Time [ms]', fontsize=15)
plt.yticks(np.arange(len(con.region_labels)), con.region_labels, fontsize=6)
plt.show()

# %% [markdown]
# <p>As you can see, no seizure is triggered anymore.</p>

# %% [markdown]
# <h1>5. Triggering a seizure by stimulation</h1>
#
# <p>We are now going to model an <b>electric stimulation</b> and <b>trigger a seizure</b>. We set the whole brain to non-epileptogenic but the stimulated regions are set closer to the threshold.</p>

# %% [markdown]
# <h3 align="left">5.1 Build a stimulus</h3>
#
# <p><div style="text-align: justify">We will begin by just arbitrarily selecting some nodes and defining the weighting of the stimuli coming into those nodes, to show what the basic process looks like.</div></p>

# %%
# Configure stimulus spatial pattern.
nodes = [62, 70]
stim_weights = np.zeros((nregions))
stim_weights[nodes] = np.array([2.0])

# %% [markdown]
# <p>We now need to define the temporal profile. This is done by selecting an equation and setting its parameters as desired.</p>

# %%
# Configure stimulus temporal profile.
eqn_t = equations.PulseTrain()
eqn_t.parameters['onset'] = 2e3       # onset time [ms]
eqn_t.parameters['T'] = 3000.0        # pulse repetition period [ms]
eqn_t.parameters['tau'] = 100.0       # pulse duration [ms]

# %% [markdown]
# <p>Now, we need to combine these spatial and temporal components into a StimuliRegion object, which can then be used in the construction of our simulator:</p>

# %%
# Configure Stimuli object.
stimulus = patterns.StimuliRegion(temporal = eqn_t,
                                  connectivity = con, 
                                  weight =stim_weights)

# %% [markdown]
# <p>We can take a quick look at the basic structure of the stimuli we have just defined using one of the built in plotting tools.</p>
#
# <p>The plotting tool we will use provides a simple overview of the stimuli's structure. It assumes the stimulus object is already configured, so we start by configuring the object. This configuration step is actually taken care of automagically within the simulator, so when you don't want to look at your stimuli before running a simulation this step isn't necessary.</p>
#
# <p><i>NOTE:</i> while the information necessary to configure space is provided by the Connectivity object, for time it is necessary to explicitly provide a time vector. When a simulation is run, this time vector is generated internally based on the integration scheme's dt and the simulation length requested when you call the simulator.</p>

# %%
# Configure space and time.
stimulus.configure_space()
stimulus.configure_time(np.arange(0., 10000., 5**-2))

# And take a look
plot_pattern(stimulus)
plt.show()

# %% [markdown]
# <h3 align="left">5.2 Simulate</h3>
#
# <p><div style="text-align: justify">Now, we just configure ...</div></p>

# %%
# Initialise Model.
epi = models.Epileptor(Ks=np.array(1.), r=np.array(0.00015))
epi.x0 = np.ones(nregions) * (-2.2) 
epi.x0[nodes] = np.ones((2)) * (-2.07)

# Set initial conditions.
epi.state_variable_range["x1"] = [-1.8, -1.8]
epi.state_variable_range["y1"] = [-15, -15]
epi.state_variable_range["z"] = [3.6, 3.6]
epi.state_variable_range["x2"] = [-1.1, -1.1]
epi.state_variable_range["y2"] = [0.001, 0.001]

# %%
# Initialise Simulator.
sim = simulator.Simulator(model=epi, 
                          connectivity=con,
                          coupling=coupling.Difference(a=np.array(-0.25)), 
                          integrator=integrators.HeunStochastic(dt=0.05, noise=noise.Additive(nsig=np.array([0., 0., 0., 0.0001, 0.0001, 0.]))), 
                          monitors=(monitors.TemporalAverage(period=1),), 
                          stimulus=stimulus)

sim.configure()
# Out:
# <table>
# <h3>Simulator</h3>
# <thead><tr><th></th><th style="text-align:left;width:40%">value</th></tr></thead>
# <tbody>
# <tr><td>Type</td><td style="text-align:left;"><pre>Simulator</pre></td>
# <tr><td>conduction_speed</td><td style="text-align:left;"><pre>3.0</pre></td>
# <tr><td>connectivity</td><td style="text-align:left;"><pre>Connectivity gid: 236af931-2170-493a-a34c-2196e9a5fc30</pre></td>
# <tr><td>coupling</td><td style="text-align:left;"><pre>Difference gid: 580fc49e-10d1-465e-9673-5fd6c8202672</pre></td>
# <tr><td>gid</td><td style="text-align:left;"><pre>UUID('9e6aa22f-c412-43b6-9690-6b0ba5677030')</pre></td>
# <tr><td>initial_conditions</td><td style="text-align:left;"><pre>None</pre></td>
# <tr><td>integrator</td><td style="text-align:left;"><pre>HeunStochastic gid: bee5ea77-8a97-465f-8d5c-d43343a035ab</pre></td>
# <tr><td>model</td><td style="text-align:left;"><pre>Epileptor gid: fd66bf31-30a3-4dbd-95af-f23866425c37</pre></td>
# <tr><td>monitors</td><td style="text-align:left;"><pre>(<tvb.simulator.monitors.TemporalAverage object at 0x12e855c10>,)</pre></td>
# <tr><td>simulation_length</td><td style="text-align:left;"><pre>1000.0</pre></td>
# <tr><td>stimulus</td><td style="text-align:left;"><pre>StimuliRegion gid: 3540e1a9-6c50-4d30-9b96-7bf1d05d149f</pre></td>
# <tr><td>surface</td><td style="text-align:left;"><pre>None</pre></td>
# <tr><td>title</td><td style="text-align:left;"><pre>Simulator gid: 9e6aa22f-c412-43b6-9690-6b0ba5677030</pre></td>
# </tbody></table>

# %% [markdown]
# <p><div style="text-align: justify">... and run the simulation.</div></p>

# %%
# Starting simulation
print("Starting simulation...")
tic = tm.time()

(t, tavg), = sim.run(simulation_length=10000) # ~90 s

# Finished simulation.  
print("Finished simulation.")
print("execute for" + str(tm.time()-tic))
# Out:
#   0%|          | 194/199999 [00:00<01:43, 1937.97it/s]
# Starting simulation...
# 200000it [01:36, 2076.57it/s]
# Finished simulation.
# execute for96.33402705192566

# %% [markdown]
# <h3 align="left">5.3 Visualize</h3>

# %%
plt.figure(figsize=(10,10))
plt.plot(t[:], tavg[:, 0, :, 0] + np.r_[:nregions], 'k', alpha=0.3)
plt.title('Stim - Epileptors time series', fontsize=15)
plt.xlabel('Time [ms]', fontsize=15)
plt.yticks(np.arange(len(con.region_labels)), con.region_labels, fontsize=6)

for i, node in enumerate(nodes):
    plt.plot(t[:], tavg[:, 0, nodes[i], 0] + nodes[i]) # , 'C0'
    
plt.show()

# %% [markdown]
# <h1><font size="6" face="arial" >Further exploration</font></h1>
#
# ***
#
# <br></br>
# <p><div style="text-align: justify">
# <ul>
# <li>Find less invasive resection strategy for stopping the seizure propagation</li>
# <ul>
# <li>Effects of a lesion are not local and are difficult to predict without a simulation</li>
# <li>Comparing the damage of the different surgical procedures</li>
# <li>resection versus random lesioning versus lesioning the strongest links</li>
# </ul>
# </ul>
# <ul>
# <li>Comparing the impact of the stimuli for trigerring seiuzure</li>
# <ul>
# <li>How strong must the stimulus be for different nodes, with different heatmaps?</li>
# </ul>
# </ul>
